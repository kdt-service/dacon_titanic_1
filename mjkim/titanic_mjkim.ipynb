# %% [markdown]
# # 타이타닉

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# # 데이터 로딩

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %% [markdown]
# # 데이터 전처리

# %%
train_demo = pd.DataFrame(train.groupby('Sex').agg(pd.Series.mode)['Age'])
train_demo
# Out:
# <ipython-input-59-1711721c48d0>:1: FutureWarning: ['PassengerId'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   train_demo = pd.DataFrame(train.groupby('Sex').agg(pd.Series.mode)['Age'])
# Age    24.0
# Name: female, dtype: object

# %%
train['Age'] = train['Age'].fillna(29)
train['Sex'] = train['Sex'].map({'male' : 0, 'female' : 1})

test['Age'] = test['Age'].fillna(29)
test['Sex'] = test['Sex'].map({'male' : 0, 'female' : 1})

# %%
train_x = train[['Pclass', 'SibSp','Age', 'Sex']]
train_y = train['Survived']

test_x = test[['Pclass', 'SibSp', 'Age', 'Sex']]

# %% [markdown]
# #모델 정의 및 학습

# %%
# 모델 만들기
model = GradientBoostingClassifier(random_state=0, max_depth=1).fit(train_x, train_y)
# 학습하기
model.fit(train_x, train_y)
# Out:
# GradientBoostingClassifier(max_depth=1, random_state=0)

# %%
test_y_pred = model.predict(test_x)

# %% [markdown]
# #제출 파일 생성

# %%
submission = pd.read_csv("./gender_submission.csv")
submission['Survived'] = test_y_pred
submission.to_csv('베이스 라인 .csv', index = False)

# %%
bass = pd.read_csv("./베이스 라인 .csv")
bass
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
